# %%
class ATM():
    def __init__(self,balance=0,check_balance=800):
        
        self.balance=balance
        self.check_balance=check_balance
    def deposit(self,amount):
        self.amount=amount
        self.balance=self.balance+self.amount
        print("Your current balance is",self.balance)
        print()
    def withdrawl(self,amount):
        self.amount=amount
        if self.amount>self.balance:
            print("There is insufficient Fund in your account")
            self.show()
        else:
            self.balance-=self.amount
            print("Your current balance is",self.balance)
            print()
    def transaction(self,p):
        self.p=p
        if self.p<=self.check_balance:
            self.check_balance-=p
            self.balance+=p
            print("Your current balance is",self.balance)
            print()
        else:
            print("There is insufficient Balance in Check Balance")
      
    def show(self):
        print("Your current balance is",self.balance)
        print()
obj=ATM()
p1=int(input("Enter Your Pin Number"))
n=str(p1)
if(len(n)==4):
    p2=int(input("Enter Pin number once again"))
m=str(p2)
if(len(n)==len(m)):
    print("Pin Verified")
else:
    print("You Entered Wrong Pin number ")
    
while True:
    try:
        o=int(input("Enter 1 for Saving Balance\nEnter 2 for Deposit\nEnter 3 for Withdrawl\nEnter 4 for Transactiion\n"))
        print()
    except:
        print("Enter the Correct Number\n")
        continue
    else:
        if o==1:
            obj.show()
        elif o==2:
            amount=int(input("enter amount for deposit"))
            obj.deposit(amount)
            
        elif o==3:
            amount=int(input("enter amount for debit"))
            if amount<obj.balance:
                obj.withdrawl(amount)
            else:
                print("Insufficient Balance in Check Balance")
        elif o==4:
            v=int(input("Enter the amount you want to transfer from check balance"))
            if p<obj.check_balance:
                obj.transaction(p)
            else:
                print("There is insufficient Balance in Check Balance")
        else:
            exit(0)
            break
# Out:
# Enter Your Pin Number1234
# Enter Pin number once again1234
# Pin Verified
# Enter 1 for Saving Balance
# Enter 2 for Deposit
# Enter 3 for Withdrawl
# Enter 4 for Transactiion
# 1
#
# Current balance is 0
#
# Enter 1 for Saving Balance
# Enter 2 for Deposit
# Enter 3 for Withdrawl
# Enter 4 for Transactiion
# 2
#
# enter amount for deposit200
# Current balance is 200
#
# Enter 1 for Saving Balance
# Enter 2 for Deposit
# Enter 3 for Withdrawl
# Enter 4 for Transactiion
# 3
#
# enter amount for debit100
# Current balance is 100
#
# Enter 1 for Saving Balance
# Enter 2 for Deposit
# Enter 3 for Withdrawl
# Enter 4 for Transactiion
# 4
#
# Enter the amount you want to transfer from check balance500
# Insufficient Balance in Check Balance
